# %%
import RegressionAnalysis
from importlib import reload
reload(RegressionAnalysis)
tests = RegressionAnalysis._TestModel()

# %%
[method_name for method_name in dir(tests)
                  if callable(getattr(tests, method_name)) and method_name.startswith('test_')]
# Out:
# ['test_compute_residuals',
#  'test_compute_vif',
#  'test_fit_model',
#  'test_make_correlation_plot',
#  'test_make_pair_plot',
#  'test_make_test_train_split',
#  'test_plot_residuals_against_inputs',
#  'test_plot_residuals_against_prediction',
#  'test_plot_residuals_distribution',
#  'test_plot_residuals_normal_qq',
#  'test_predict_target']

# %%
tests.test_compute_residuals()
# Out:
# True

# %%
tests.test_compute_vif()
# Out:
# True

# %%
tests.test_fit_model()
# Out:
# True

# %%
tests.test_make_correlation_plot()
# Out:
# True

# %%
tests.test_make_pair_plot()
# Out:
# True

# %%
tests.test_make_test_train_split()
# Out:
# True

# %%
tests.test_plot_residuals_against_inputs()
# Out:
# True

# %%
tests.test_plot_residuals_against_prediction()
# Out:
# True

# %%
tests.test_plot_residuals_distribution()
# Out:
# True

# %%
tests.test_plot_residuals_normal_qq()
# Out:
# True

# %%
tests.test_predict_target()
# Out:
# True
